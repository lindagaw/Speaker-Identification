# %%
from pydub import AudioSegment
import time
import datetime
import os
import numpy as np

import pickle

import random
from xml.dom import minidom
from librosa import load
import shutil

from extract_feat import extract_feats_single_wav
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier


from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

from mlxtend.feature_selection import SequentialFeatureSelector as sfs

path_caregiver = 'speaker_id_module//SpeakerID//singles//1-caregiver//'
dest_caregiver = 'app//2-Training//singles//1-caregiver//'

path_patient = 'speaker_id_module//SpeakerID//singles//2-patient//'
dest_patient = 'app//2-Training//singles//2-patient//'

def slice_audios(path, dest):
    for old_audio in os.listdir(dest):
        os.remove(dest + old_audio)
        
    for audio_index in range(0, len(os.listdir(path))):
        target_audio_path =  path + os.listdir(path)[audio_index]
        print('input audio: ' + target_audio_path)

        target_audio = AudioSegment.from_wav(target_audio_path)
        target_duration = target_audio.duration_seconds

        folds = int(target_duration/5.0)
        for fold in range(0, folds+1):

            start_time = time.time()

            start_time = fold * 5000  # Works in milliseconds
            end_time = (fold + 1) * 5000
            new_audio = target_audio[start_time:end_time]

            components = target_audio_path.split('/')
            filename = components[len(components)-1]

            new_audio_path = dest + filename[:len(filename)-4] + '_' + str(fold) + '.wav'
            print('generated the slice of the audio segment at index ' + str(fold) )
            new_audio.export(new_audio_path, format="wav")

def change_amplitude(emotionfile, d1, newSoundFile, d2):
    
    if d1 <= d2:
        sound = AudioSegment.from_file(emotionfile) - np.random.randint(0, (6 * d2/d1 - 1))
        sound.export(newSoundFile, format='wav')  ### save the new generated file in a folder
    else:
        print('Invalid distance parameters. d1 should be <= d2.')

def change_amplitude_range(emotionfile, newSoundFile, threshold):
    #amount = np.random.randint(0, threshold)
    amount = random.uniform(0, threshold)
    #print('Deamplify ' + str(emotionfile) + ' by ' + str(amount) + ' db.')
    sound = AudioSegment.from_file(emotionfile) - amount
    sound.export(newSoundFile, format='wav')  ### save the new generated file in a folder
    return amount

def deamplify_per_folder(directory):
    for file in os.listdir(directory):
        if file.endswith('.wav'):
            soundFile = directory + file
            newSoundFile = directory + 'deamplified_' + file
            change_amplitude_range(soundFile, newSoundFile, 12)

def add_noise_and_deamplify_per_folder(directory, extension, noise_directory):
    for file in os.listdir(directory):
        if file.endswith(extension) and not file[1] == '_':
            for i in range(0, 2):
                soundFile = directory + file
                amount = change_amplitude_range(soundFile, soundFile, 6)
                noise = random.choice(os.listdir(noise_directory))
                random_noise = noise_directory + noise
                newSoundFile = directory + 'deamp_' + str(amount) + '_noise_' + noise[:len(noise)-5] + '_' + file
                add_noise_per_file(soundFile, random_noise, newSoundFile)
                print(newSoundFile)

def add_noise_per_file(emotionfile, bgnoise, newSoundFile):
    
    emotionsound = AudioSegment.from_wav(emotionfile)
    emotion_duration = emotionsound.duration_seconds * 1000
    noise = AudioSegment.from_wav(bgnoise)
    noise_duration = noise.duration_seconds * 1000
    
    threshold = noise_duration - emotion_duration
    
    if threshold > 0:
        overlay_start = np.random.randint(0, threshold)
    else:
        overlay_start = 0
        
    targeted_chunk = noise[overlay_start:overlay_start + emotion_duration]
    newSound = emotionsound.overlay(targeted_chunk, position=0)
    newSound=newSound[0:5000]
    newSound.export(newSoundFile, format='wav')  ### save the new generated file in a folder

def extract_features_for_all_wavs(dest, label):
    result = np.expand_dims(np.zeros((48, 272)), axis=0)

    for wav in os.listdir(dest):
        vec = extract_feats_single_wav(dest + wav)
        if not str(vec.shape) == '(48, 272)':
            continue
        result = np.vstack((result, np.expand_dims(vec, axis=0)))

    result = result[1:]
    labels = np.expand_dims(np.asarray([label] * len(result)), axis=1)
    print(result.shape)
    print(labels.shape)

    return result, labels



import tensorflow as tf

from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.constraints import maxnorm
from keras.layers import Convolution1D, Dense, MaxPooling1D, Flatten, Add, Dropout, Input, Activation
from keras.layers import TimeDistributed, Bidirectional, LSTM, LeakyReLU
from keras.models import Sequential
from keras import optimizers, regularizers
from keras.utils import np_utils, to_categorical
from keras.models import Model, load_model, Sequential
from keras.regularizers import l2

import keras

from IPython.display import clear_output
from tensorflow.python.client import device_lib
from tensorflow.python.keras import backend
import tensorflow as tf


print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.keras.backend.clear_session()
tf.compat.v1.reset_default_graph()

def mil_squared_error(y_true, y_pred):
    return tf.keras.backend.square(tf.keras.backend.max(y_pred) - tf.keras.backend.max(y_true))

adam = tf.keras.optimizers.Adam(learning_rate=1e-5)

def train_cnn():

    model = keras.Sequential()
    model.add(Convolution1D(filters= 1500, kernel_size=2, strides=2, activation='relu', input_shape=X_train[0].shape))
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.2))

    model = keras.Sequential()
    model.add(Convolution1D(filters= 500, kernel_size=2, strides=2, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.2))

    model = keras.Sequential()
    model.add(Convolution1D(filters= 500, kernel_size=2, strides=2, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.2))

    model = keras.Sequential()
    model.add(Convolution1D(filters= 500, kernel_size=2, strides=2, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Dropout(0.2))

    model.add(Flatten())

    for i in range(0, 1):
        model.add(Dense(256, activation="relu"))
        model.add(Dropout(0.2))
    model.add(Dense(2, activation="softmax"))
    model.compile(loss=['categorical_crossentropy'], optimizer=adam, metrics=['accuracy', mil_squared_error])
    
    print("Fit model on training data")
    history = model.fit(
        X_train,
        y_train,
        batch_size=64,
        epochs=150,
        validation_data=(X_val, y_val), verbose=1
    )

    #from sklearn.metrics import f1_score

    y_preds = [np.argmax(val) for val in model.predict(X_test)]
    y_trues = [np.argmax(val) for val in y_test]
    print(accuracy_score(y_trues, y_preds))

    model.save('models//cnn.hdf5')

    return model



# STEP 1: slice into 5-second wavs
slice_audios(path_caregiver, dest_caregiver)
slice_audios(path_patient, dest_patient)
noise_directory = 'D://Background_noise//noise_home//'

add_noise_and_deamplify_per_folder(dest_caregiver, '.wav', noise_directory)
add_noise_and_deamplify_per_folder(dest_patient, '.wav', noise_directory)

# Step 2: get the vecs of shape (X, 48, 272)
X_caregiver, y_caregiver = extract_features_for_all_wavs(dest_caregiver, 0)
X_patient, y_patient = extract_features_for_all_wavs(dest_patient, 1)

X = np.vstack((X_caregiver, X_patient))
y = to_categorical( np.vstack((y_caregiver, y_patient)) )

#nsamples, nx, ny = X.shape
#X = X.reshape((nsamples,nx*ny))

X, X_test, y, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=42)

model = train_cnn()

intermediate_layer_model = keras.Model(inputs=model.input,
                                    outputs=model.get_layer(index=len(model.layers)-2).output)
intermediate_layer_model.summary()
# Out:
# C:\Users\Ash Gao\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Number of features are unspecified. Defaut is set to = 272.
# Using TensorFlow backend.
# Num GPUs Available:  0
# input audio: speaker_id_module//SpeakerID//singles//1-caregiver//caregiver.wav
# generated the slice of the audio segment at index 0
# generated the slice of the audio segment at index 1
# generated the slice of the audio segment at index 2
# generated the slice of the audio segment at index 3
# generated the slice of the audio segment at index 4
# generated the slice of the audio segment at index 5
# generated the slice of the audio segment at index 6
# generated the slice of the audio segment at index 7
# generated the slice of the audio segment at index 8
# generated the slice of the audio segment at index 9
# generated the slice of the audio segment at index 10
# generated the slice of the audio segment at index 11
# generated the slice of the audio segment at index 12
# generated the slice of the audio segment at index 13
# generated the slice of the audio segment at index 14
# generated the slice of the audio segment at index 15
# generated the slice of the audio segment at index 16
# generated the slice of the audio segment at index 17
# generated the slice of the audio segment at index 18
# generated the slice of the audio segment at index 19
# generated the slice of the audio segment at index 20
# generated the slice of the audio segment at index 21
# generated the slice of the audio segment at index 22
# generated the slice of the audio segment at index 23
# generated the slice of the audio segment at index 24
# generated the slice of the audio segment at index 25
# generated the slice of the audio segment at index 26
# generated the slice of the audio segment at index 27
# generated the slice of the audio segment at index 28
# generated the slice of the audio segment at index 29
# generated the slice of the audio segment at index 30
# generated the slice of the audio segment at index 31
# generated the slice of the audio segment at index 32
# generated the slice of the audio segment at index 33
# generated the slice of the audio segment at index 34
# generated the slice of the audio segment at index 35
# generated the slice of the audio segment at index 36
# generated the slice of the audio segment at index 37
# generated the slice of the audio segment at index 38
# generated the slice of the audio segment at index 39
# generated the slice of the audio segment at index 40
# generated the slice of the audio segment at index 41
# generated the slice of the audio segment at index 42
# generated the slice of the audio segment at index 43
# generated the slice of the audio segment at index 44
# generated the slice of the audio segment at index 45
# generated the slice of the audio segment at index 46
# generated the slice of the audio segment at index 47
# generated the slice of the audio segment at index 48
# generated the slice of the audio segment at index 49
# generated the slice of the audio segment at index 50
# generated the slice of the audio segment at index 51
# generated the slice of the audio segment at index 52
# generated the slice of the audio segment at index 53
# generated the slice of the audio segment at index 54
# generated the slice of the audio segment at index 55
# generated the slice of the audio segment at index 56
# generated the slice of the audio segment at index 57
# generated the slice of the audio segment at index 58
# generated the slice of the audio segment at index 59
# input audio: speaker_id_module//SpeakerID//singles//2-patient//patient.wav
# generated the slice of the audio segment at index 0
# generated the slice of the audio segment at index 1
# generated the slice of the audio segment at index 2
# generated the slice of the audio segment at index 3
# generated the slice of the audio segment at index 4
# generated the slice of the audio segment at index 5
# generated the slice of the audio segment at index 6
# generated the slice of the audio segment at index 7
# generated the slice of the audio segment at index 8
# generated the slice of the audio segment at index 9
# generated the slice of the audio segment at index 10
# generated the slice of the audio segment at index 11
# generated the slice of the audio segment at index 12
# generated the slice of the audio segment at index 13
# generated the slice of the audio segment at index 14
# generated the slice of the audio segment at index 15
# generated the slice of the audio segment at index 16
# generated the slice of the audio segment at index 17
# generated the slice of the audio segment at index 18
# generated the slice of the audio segment at index 19
# generated the slice of the audio segment at index 20
# generated the slice of the audio segment at index 21
# generated the slice of the audio segment at index 22
# generated the slice of the audio segment at index 23
# generated the slice of the audio segment at index 24
# generated the slice of the audio segment at index 25
# generated the slice of the audio segment at index 26
# generated the slice of the audio segment at index 27
# generated the slice of the audio segment at index 28
# generated the slice of the audio segment at index 29
# generated the slice of the audio segment at index 30
# generated the slice of the audio segment at index 31
# generated the slice of the audio segment at index 32
# generated the slice of the audio segment at index 33
# generated the slice of the audio segment at index 34
# generated the slice of the audio segment at index 35
# generated the slice of the audio segment at index 36
# generated the slice of the audio segment at index 37
# generated the slice of the audio segment at index 38
# generated the slice of the audio segment at index 39
# generated the slice of the audio segment at index 40
# generated the slice of the audio segment at index 41
# generated the slice of the audio segment at index 42
# generated the slice of the audio segment at index 43
# generated the slice of the audio segment at index 44
# generated the slice of the audio segment at index 45
# generated the slice of the audio segment at index 46
# generated the slice of the audio segment at index 47
# generated the slice of the audio segment at index 48
# generated the slice of the audio segment at index 49
# generated the slice of the audio segment at index 50
# generated the slice of the audio segment at index 51
# generated the slice of the audio segment at index 52
# generated the slice of the audio segment at index 53
# generated the slice of the audio segment at index 54
# generated the slice of the audio segment at index 55
# generated the slice of the audio segment at index 56
# generated the slice of the audio segment at index 57
# generated the slice of the audio segment at index 58
# generated the slice of the audio segment at index 59
# app//2-Training//singles//1-caregiver//deamp_4.122387756741984_noise_home_2_caregiver_0.wav
# app//2-Training//singles//1-caregiver//deamp_5.985148389874611_noise_home_25_caregiver_0.wav
# app//2-Training//singles//1-caregiver//deamp_2.914357635137258_noise_home_82_caregiver_1.wav
# app//2-Training//singles//1-caregiver//deamp_4.817228702247248_noise_home_82_caregiver_1.wav
# app//2-Training//singles//1-caregiver//deamp_5.5914239274291155_noise_home_2_caregiver_2.wav
# app//2-Training//singles//1-caregiver//deamp_3.384613294402225_noise_home_82_caregiver_2.wav
# app//2-Training//singles//1-caregiver//deamp_4.795876407803801_noise_home_23_caregiver_3.wav
# app//2-Training//singles//1-caregiver//deamp_4.591408738454352_noise_home_23_caregiver_3.wav
# app//2-Training//singles//1-caregiver//deamp_0.8861571336041227_noise_home_23_caregiver_4.wav
# app//2-Training//singles//1-caregiver//deamp_4.494621203937094_noise_home_83_caregiver_4.wav
# app//2-Training//singles//1-caregiver//deamp_2.744888568981006_noise_home_82_caregiver_5.wav
# app//2-Training//singles//1-caregiver//deamp_2.8930211641668655_noise_home_26_caregiver_5.wav
# app//2-Training//singles//1-caregiver//deamp_2.5414997235732537_noise_home_81_caregiver_6.wav
# app//2-Training//singles//1-caregiver//deamp_5.129898127822801_noise_home_24_caregiver_6.wav
# app//2-Training//singles//1-caregiver//deamp_3.195189015609961_noise_home_81_caregiver_7.wav
# app//2-Training//singles//2-patient//deamp_3.2685497063408855_noise_home_82_patient_48.wav
# app//2-Training//singles//2-patient//deamp_2.735447838002944_noise_home_82_patient_49.wav
# app//2-Training//singles//2-patient//deamp_4.0523090304006395_noise_home_80_patient_49.wav
# app//2-Training//singles//2-patient//deamp_0.9852771760151553_noise_home_82_patient_50.wav
# app//2-Training//singles//2-patient//deamp_0.5506429934791688_noise_home_81_patient_50.wav
# app//2-Training//singles//2-patient//deamp_0.26866912879568816_noise_home_81_patient_51.wav
# app//2-Training//singles//2-patient//deamp_2.1120805496543014_noise_home_23_patient_51.wav
# app//2-Training//singles//2-patient//deamp_5.775852824975498_noise_home_23_patient_52.wav
# app//2-Training//singles//2-patient//deamp_5.73571213861673_noise_home_25_patient_52.wav
# app//2-Training//singles//2-patient//deamp_5.610763717526195_noise_home_26_patient_53.wav
# app//2-Training//singles//2-patient//deamp_3.1318641053910583_noise_home_81_patient_53.wav
# app//2-Training//singles//2-patient//deamp_1.250392856062023_noise_home_80_patient_54.wav
# app//2-Training//singles//2-patient//deamp_5.398534023535944_noise_home_25_patient_54.wav
# app//2-Training//singles//2-patient//deamp_5.909241877138583_noise_home_80_patient_55.wav
# app//2-Training//singles//2-patient//deamp_0.3751240602566057_noise_home_82_patient_55.wav
# app//2-Training//singles//2-patient//deamp_4.500098486532767_noise_home_24_patient_56.wav
# app//2-Training//singles//2-patient//deamp_2.7443502701876694_noise_home_88_patient_56.wav
# app//2-Training//singles//2-patient//deamp_5.262740102890255_noise_home_25_patient_57.wav
# app//2-Training//singles//2-patient//deamp_3.388095544581429_noise_home_88_patient_57.wav
# app//2-Training//singles//2-patient//deamp_4.598720005370477_noise_home_82_patient_58.wav
# app//2-Training//singles//2-patient//deamp_2.5673076549520903_noise_home_23_patient_58.wav
# app//2-Training//singles//2-patient//deamp_0.82867051311868_noise_home_2_patient_59.wav
# app//2-Training//singles//2-patient//deamp_2.2195186271829_noise_home_25_patient_59.wav
# (180, 48, 272)
# (180, 1)
# (180, 48, 272)
# (180, 1)
# Fit model on training data
# Train on 180 samples, validate on 61 samples
# Epoch 1/150
# 180/180 [==============================] - 0s 1ms/step - loss: 0.7142 - accuracy: 0.4611 - mil_squared_error: 0.1291 - val_loss: 0.6904 - val_accuracy: 0.5738 - val_mil_squared_error: 0.1820
# Epoch 2/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.6944 - accuracy: 0.5389 - mil_squared_error: 0.1400 - val_loss: 0.6836 - val_accuracy: 0.6230 - val_mil_squared_error: 0.1847
# Epoch 3/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.6822 - accuracy: 0.6111 - mil_squared_error: 0.1396 - val_loss: 0.6771 - val_accuracy: 0.6393 - val_mil_squared_error: 0.1796
# Epoch 4/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.6791 - accuracy: 0.5889 - mil_squared_error: 0.1333 - val_loss: 0.6707 - val_accuracy: 0.7049 - val_mil_squared_error: 0.1797
# Epoch 5/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.6724 - accuracy: 0.6056 - mil_squared_error: 0.1451 - val_loss: 0.6645 - val_accuracy: 0.7049 - val_mil_squared_error: 0.1790
# Epoch 6/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.6682 - accuracy: 0.5944 - mil_squared_error: 0.1286 - val_loss: 0.6584 - val_accuracy: 0.7213 - val_mil_squared_error: 0.1754
# Epoch 7/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.6597 - accuracy: 0.6056 - mil_squared_error: 0.1216 - val_loss: 0.6523 - val_accuracy: 0.7213 - val_mil_squared_error: 0.1730
# Epoch 8/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.6552 - accuracy: 0.6889 - mil_squared_error: 0.1389 - val_loss: 0.6464 - val_accuracy: 0.7213 - val_mil_squared_error: 0.1697
# Epoch 9/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.6479 - accuracy: 0.6889 - mil_squared_error: 0.1334 - val_loss: 0.6405 - val_accuracy: 0.7705 - val_mil_squared_error: 0.1648
# Epoch 10/150
# 180/180 [==============================] - 0s 665us/step - loss: 0.6375 - accuracy: 0.7389 - mil_squared_error: 0.1277 - val_loss: 0.6346 - val_accuracy: 0.7869 - val_mil_squared_error: 0.1586
# Epoch 11/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.6319 - accuracy: 0.7222 - mil_squared_error: 0.1308 - val_loss: 0.6287 - val_accuracy: 0.8033 - val_mil_squared_error: 0.1546
# Epoch 12/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.6207 - accuracy: 0.7889 - mil_squared_error: 0.1092 - val_loss: 0.6227 - val_accuracy: 0.8525 - val_mil_squared_error: 0.1508
# Epoch 13/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.6201 - accuracy: 0.8111 - mil_squared_error: 0.1273 - val_loss: 0.6167 - val_accuracy: 0.8689 - val_mil_squared_error: 0.1494
# Epoch 14/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.6076 - accuracy: 0.8333 - mil_squared_error: 0.1097 - val_loss: 0.6108 - val_accuracy: 0.8689 - val_mil_squared_error: 0.1462
# Epoch 15/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.6066 - accuracy: 0.8111 - mil_squared_error: 0.1227 - val_loss: 0.6048 - val_accuracy: 0.9180 - val_mil_squared_error: 0.1445
# Epoch 16/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.5969 - accuracy: 0.8222 - mil_squared_error: 0.1229 - val_loss: 0.5986 - val_accuracy: 0.9508 - val_mil_squared_error: 0.1435
# Epoch 17/150
# 180/180 [==============================] - 0s 670us/step - loss: 0.5852 - accuracy: 0.9167 - mil_squared_error: 0.1079 - val_loss: 0.5926 - val_accuracy: 0.9508 - val_mil_squared_error: 0.1402
# Epoch 18/150
# 180/180 [==============================] - 0s 665us/step - loss: 0.5903 - accuracy: 0.8500 - mil_squared_error: 0.1087 - val_loss: 0.5864 - val_accuracy: 0.9508 - val_mil_squared_error: 0.1375
# Epoch 19/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.5819 - accuracy: 0.8833 - mil_squared_error: 0.1085 - val_loss: 0.5803 - val_accuracy: 0.9508 - val_mil_squared_error: 0.1358
# Epoch 20/150
# 180/180 [==============================] - 0s 670us/step - loss: 0.5728 - accuracy: 0.9222 - mil_squared_error: 0.0898 - val_loss: 0.5741 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1338
# Epoch 21/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.5637 - accuracy: 0.9056 - mil_squared_error: 0.0950 - val_loss: 0.5678 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1316
# Epoch 22/150
# 180/180 [==============================] - 0s 676us/step - loss: 0.5554 - accuracy: 0.9333 - mil_squared_error: 0.0874 - val_loss: 0.5613 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1285
# Epoch 23/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.5532 - accuracy: 0.9278 - mil_squared_error: 0.0875 - val_loss: 0.5548 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1233
# Epoch 24/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.5465 - accuracy: 0.9278 - mil_squared_error: 0.0865 - val_loss: 0.5483 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1197
# Epoch 25/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.5453 - accuracy: 0.9278 - mil_squared_error: 0.0863 - val_loss: 0.5418 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1139
# Epoch 26/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.5253 - accuracy: 0.9389 - mil_squared_error: 0.0741 - val_loss: 0.5351 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1114
# Epoch 27/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.5182 - accuracy: 0.9667 - mil_squared_error: 0.0802 - val_loss: 0.5283 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1091
# Epoch 28/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.5118 - accuracy: 0.9500 - mil_squared_error: 0.0765 - val_loss: 0.5216 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1054
# Epoch 29/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.5164 - accuracy: 0.9278 - mil_squared_error: 0.0677 - val_loss: 0.5148 - val_accuracy: 0.9836 - val_mil_squared_error: 0.1019
# Epoch 30/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.5029 - accuracy: 0.9667 - mil_squared_error: 0.0708 - val_loss: 0.5078 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0977
# Epoch 31/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.4926 - accuracy: 0.9722 - mil_squared_error: 0.0682 - val_loss: 0.5009 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0952
# Epoch 32/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.4939 - accuracy: 0.9556 - mil_squared_error: 0.0643 - val_loss: 0.4940 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0930
# Epoch 33/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.4757 - accuracy: 0.9778 - mil_squared_error: 0.0665 - val_loss: 0.4871 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0886
# Epoch 34/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.4710 - accuracy: 0.9778 - mil_squared_error: 0.0542 - val_loss: 0.4802 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0863
# Epoch 35/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.4601 - accuracy: 0.9722 - mil_squared_error: 0.0500 - val_loss: 0.4732 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0843
# Epoch 36/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.4546 - accuracy: 0.9778 - mil_squared_error: 0.0509 - val_loss: 0.4664 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0825
# Epoch 37/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.4539 - accuracy: 0.9833 - mil_squared_error: 0.0454 - val_loss: 0.4596 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0816
# Epoch 38/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.4421 - accuracy: 0.9833 - mil_squared_error: 0.0419 - val_loss: 0.4528 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0767
# Epoch 39/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.4402 - accuracy: 0.9722 - mil_squared_error: 0.0476 - val_loss: 0.4460 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0720
# Epoch 40/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.4328 - accuracy: 0.9889 - mil_squared_error: 0.0475 - val_loss: 0.4393 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0705
# Epoch 41/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.4295 - accuracy: 0.9944 - mil_squared_error: 0.0512 - val_loss: 0.4326 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0672
# Epoch 42/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.4202 - accuracy: 0.9889 - mil_squared_error: 0.0450 - val_loss: 0.4259 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0644
# Epoch 43/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.4050 - accuracy: 0.9833 - mil_squared_error: 0.0362 - val_loss: 0.4193 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0624
# Epoch 44/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.4060 - accuracy: 0.9778 - mil_squared_error: 0.0301 - val_loss: 0.4126 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0604
# Epoch 45/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.3967 - accuracy: 0.9944 - mil_squared_error: 0.0395 - val_loss: 0.4061 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0580
# Epoch 46/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.3865 - accuracy: 1.0000 - mil_squared_error: 0.0309 - val_loss: 0.3996 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0562
# Epoch 47/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.3815 - accuracy: 1.0000 - mil_squared_error: 0.0396 - val_loss: 0.3931 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0538
# Epoch 48/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.3746 - accuracy: 1.0000 - mil_squared_error: 0.0325 - val_loss: 0.3866 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0514
# Epoch 49/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.3646 - accuracy: 0.9944 - mil_squared_error: 0.0279 - val_loss: 0.3801 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0490
# Epoch 50/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.3588 - accuracy: 0.9944 - mil_squared_error: 0.0331 - val_loss: 0.3737 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0473
# Epoch 51/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.3570 - accuracy: 1.0000 - mil_squared_error: 0.0243 - val_loss: 0.3673 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0437
# Epoch 52/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.3547 - accuracy: 0.9944 - mil_squared_error: 0.0231 - val_loss: 0.3610 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0421
# Epoch 53/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.3432 - accuracy: 0.9944 - mil_squared_error: 0.0239 - val_loss: 0.3548 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0394
# Epoch 54/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.3375 - accuracy: 1.0000 - mil_squared_error: 0.0216 - val_loss: 0.3486 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0382
# Epoch 55/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.3372 - accuracy: 0.9889 - mil_squared_error: 0.0185 - val_loss: 0.3426 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0368
# Epoch 56/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.3225 - accuracy: 1.0000 - mil_squared_error: 0.0203 - val_loss: 0.3366 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0354
# Epoch 57/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.3142 - accuracy: 1.0000 - mil_squared_error: 0.0169 - val_loss: 0.3306 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0335
# Epoch 58/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.3160 - accuracy: 1.0000 - mil_squared_error: 0.0173 - val_loss: 0.3247 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0304
# Epoch 59/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.2966 - accuracy: 1.0000 - mil_squared_error: 0.0158 - val_loss: 0.3189 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0285
# Epoch 60/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.2955 - accuracy: 1.0000 - mil_squared_error: 0.0153 - val_loss: 0.3131 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0266
# Epoch 61/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.2924 - accuracy: 0.9944 - mil_squared_error: 0.0120 - val_loss: 0.3074 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0254
# Epoch 62/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.2895 - accuracy: 1.0000 - mil_squared_error: 0.0163 - val_loss: 0.3018 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0248
# Epoch 63/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.2750 - accuracy: 1.0000 - mil_squared_error: 0.0112 - val_loss: 0.2962 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0232
# Epoch 64/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.2700 - accuracy: 1.0000 - mil_squared_error: 0.0111 - val_loss: 0.2907 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0217
# Epoch 65/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.2605 - accuracy: 1.0000 - mil_squared_error: 0.0085 - val_loss: 0.2854 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0199
# Epoch 66/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.2623 - accuracy: 1.0000 - mil_squared_error: 0.0091 - val_loss: 0.2801 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0184
# Epoch 67/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.2553 - accuracy: 1.0000 - mil_squared_error: 0.0098 - val_loss: 0.2748 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0173
# Epoch 68/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.2506 - accuracy: 1.0000 - mil_squared_error: 0.0091 - val_loss: 0.2696 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0166
# Epoch 69/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.2429 - accuracy: 1.0000 - mil_squared_error: 0.0124 - val_loss: 0.2645 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0159
# Epoch 70/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.2427 - accuracy: 1.0000 - mil_squared_error: 0.0087 - val_loss: 0.2594 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0151
# Epoch 71/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.2416 - accuracy: 1.0000 - mil_squared_error: 0.0078 - val_loss: 0.2545 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0142
# Epoch 72/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.2324 - accuracy: 1.0000 - mil_squared_error: 0.0073 - val_loss: 0.2495 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0130
# Epoch 73/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.2321 - accuracy: 1.0000 - mil_squared_error: 0.0097 - val_loss: 0.2447 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0120
# Epoch 74/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.2214 - accuracy: 1.0000 - mil_squared_error: 0.0076 - val_loss: 0.2400 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0108
# Epoch 75/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.2169 - accuracy: 1.0000 - mil_squared_error: 0.0054 - val_loss: 0.2354 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0100
# Epoch 76/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.2082 - accuracy: 1.0000 - mil_squared_error: 0.0053 - val_loss: 0.2309 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0093
# Epoch 77/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.2121 - accuracy: 1.0000 - mil_squared_error: 0.0047 - val_loss: 0.2265 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0087
# Epoch 78/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.2091 - accuracy: 1.0000 - mil_squared_error: 0.0061 - val_loss: 0.2221 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0081
# Epoch 79/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.2002 - accuracy: 1.0000 - mil_squared_error: 0.0042 - val_loss: 0.2179 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0075
# Epoch 80/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1939 - accuracy: 1.0000 - mil_squared_error: 0.0051 - val_loss: 0.2137 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0069
# Epoch 81/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1902 - accuracy: 1.0000 - mil_squared_error: 0.0046 - val_loss: 0.2095 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0066
# Epoch 82/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.1805 - accuracy: 1.0000 - mil_squared_error: 0.0034 - val_loss: 0.2054 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0063
# Epoch 83/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.1770 - accuracy: 1.0000 - mil_squared_error: 0.0039 - val_loss: 0.2015 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0058
# Epoch 84/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.1789 - accuracy: 1.0000 - mil_squared_error: 0.0039 - val_loss: 0.1977 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0053
# Epoch 85/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1821 - accuracy: 1.0000 - mil_squared_error: 0.0036 - val_loss: 0.1938 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0051
# Epoch 86/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.1760 - accuracy: 1.0000 - mil_squared_error: 0.0040 - val_loss: 0.1900 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0049
# Epoch 87/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1693 - accuracy: 1.0000 - mil_squared_error: 0.0032 - val_loss: 0.1864 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0044
# Epoch 88/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.1716 - accuracy: 1.0000 - mil_squared_error: 0.0029 - val_loss: 0.1827 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0043
# Epoch 89/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.1564 - accuracy: 1.0000 - mil_squared_error: 0.0019 - val_loss: 0.1792 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0041
# Epoch 90/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1586 - accuracy: 1.0000 - mil_squared_error: 0.0023 - val_loss: 0.1757 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0039
# Epoch 91/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1491 - accuracy: 1.0000 - mil_squared_error: 0.0018 - val_loss: 0.1724 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0035
# Epoch 92/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1551 - accuracy: 1.0000 - mil_squared_error: 0.0016 - val_loss: 0.1690 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0033
# Epoch 93/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.1508 - accuracy: 1.0000 - mil_squared_error: 0.0015 - val_loss: 0.1657 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0031
# Epoch 94/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.1511 - accuracy: 1.0000 - mil_squared_error: 0.0017 - val_loss: 0.1624 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0029
# Epoch 95/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1408 - accuracy: 1.0000 - mil_squared_error: 0.0015 - val_loss: 0.1593 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0026
# Epoch 96/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1353 - accuracy: 1.0000 - mil_squared_error: 7.3288e-04 - val_loss: 0.1562 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0023
# Epoch 97/150
# 180/180 [==============================] - 0s 665us/step - loss: 0.1304 - accuracy: 1.0000 - mil_squared_error: 0.0014 - val_loss: 0.1533 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0021
# Epoch 98/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1289 - accuracy: 1.0000 - mil_squared_error: 0.0015 - val_loss: 0.1505 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0019
# Epoch 99/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1296 - accuracy: 1.0000 - mil_squared_error: 0.0013 - val_loss: 0.1474 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0019
# Epoch 100/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.1228 - accuracy: 1.0000 - mil_squared_error: 0.0012 - val_loss: 0.1445 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0019
# Epoch 101/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1258 - accuracy: 1.0000 - mil_squared_error: 0.0014 - val_loss: 0.1418 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0018
# Epoch 102/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1210 - accuracy: 1.0000 - mil_squared_error: 0.0014 - val_loss: 0.1391 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0017
# Epoch 103/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1239 - accuracy: 1.0000 - mil_squared_error: 0.0012 - val_loss: 0.1365 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0016
# Epoch 104/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.1177 - accuracy: 1.0000 - mil_squared_error: 0.0011 - val_loss: 0.1339 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0015
# Epoch 105/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.1136 - accuracy: 1.0000 - mil_squared_error: 8.0654e-04 - val_loss: 0.1313 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0014
# Epoch 106/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1136 - accuracy: 1.0000 - mil_squared_error: 7.8714e-04 - val_loss: 0.1290 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0012
# Epoch 107/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1105 - accuracy: 1.0000 - mil_squared_error: 6.6206e-04 - val_loss: 0.1266 - val_accuracy: 1.0000 - val_mil_squared_error: 0.0011
# Epoch 108/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.1113 - accuracy: 1.0000 - mil_squared_error: 7.1723e-04 - val_loss: 0.1243 - val_accuracy: 1.0000 - val_mil_squared_error: 9.8205e-04
# Epoch 109/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.1050 - accuracy: 1.0000 - mil_squared_error: 5.5468e-04 - val_loss: 0.1220 - val_accuracy: 1.0000 - val_mil_squared_error: 9.2475e-04
# Epoch 110/150
# 180/180 [==============================] - 0s 621us/step - loss: 0.1004 - accuracy: 1.0000 - mil_squared_error: 7.2525e-04 - val_loss: 0.1198 - val_accuracy: 1.0000 - val_mil_squared_error: 8.5505e-04
# Epoch 111/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.0999 - accuracy: 1.0000 - mil_squared_error: 7.7411e-04 - val_loss: 0.1176 - val_accuracy: 1.0000 - val_mil_squared_error: 8.1655e-04
# Epoch 112/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0997 - accuracy: 1.0000 - mil_squared_error: 6.2716e-04 - val_loss: 0.1153 - val_accuracy: 1.0000 - val_mil_squared_error: 7.9475e-04
# Epoch 113/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0983 - accuracy: 1.0000 - mil_squared_error: 6.1183e-04 - val_loss: 0.1132 - val_accuracy: 1.0000 - val_mil_squared_error: 7.6650e-04
# Epoch 114/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.0943 - accuracy: 1.0000 - mil_squared_error: 5.3532e-04 - val_loss: 0.1111 - val_accuracy: 1.0000 - val_mil_squared_error: 7.6367e-04
# Epoch 115/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0938 - accuracy: 1.0000 - mil_squared_error: 5.2673e-04 - val_loss: 0.1091 - val_accuracy: 1.0000 - val_mil_squared_error: 7.3396e-04
# Epoch 116/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0936 - accuracy: 1.0000 - mil_squared_error: 3.5443e-04 - val_loss: 0.1071 - val_accuracy: 1.0000 - val_mil_squared_error: 6.6152e-04
# Epoch 117/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0912 - accuracy: 1.0000 - mil_squared_error: 3.9584e-04 - val_loss: 0.1053 - val_accuracy: 1.0000 - val_mil_squared_error: 6.1676e-04
# Epoch 118/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0885 - accuracy: 1.0000 - mil_squared_error: 2.9188e-04 - val_loss: 0.1034 - val_accuracy: 1.0000 - val_mil_squared_error: 5.6386e-04
# Epoch 119/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.0872 - accuracy: 1.0000 - mil_squared_error: 4.2563e-04 - val_loss: 0.1016 - val_accuracy: 1.0000 - val_mil_squared_error: 5.3114e-04
# Epoch 120/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0820 - accuracy: 1.0000 - mil_squared_error: 4.0897e-04 - val_loss: 0.0998 - val_accuracy: 1.0000 - val_mil_squared_error: 5.0082e-04
# Epoch 121/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.0803 - accuracy: 1.0000 - mil_squared_error: 3.3280e-04 - val_loss: 0.0981 - val_accuracy: 1.0000 - val_mil_squared_error: 4.5502e-04
# Epoch 122/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.0801 - accuracy: 1.0000 - mil_squared_error: 3.7372e-04 - val_loss: 0.0965 - val_accuracy: 1.0000 - val_mil_squared_error: 4.2692e-04
# Epoch 123/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.0787 - accuracy: 1.0000 - mil_squared_error: 2.4575e-04 - val_loss: 0.0948 - val_accuracy: 1.0000 - val_mil_squared_error: 4.0886e-04
# Epoch 124/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0765 - accuracy: 1.0000 - mil_squared_error: 3.0444e-04 - val_loss: 0.0932 - val_accuracy: 1.0000 - val_mil_squared_error: 3.9101e-04
# Epoch 125/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0783 - accuracy: 1.0000 - mil_squared_error: 2.9028e-04 - val_loss: 0.0916 - val_accuracy: 1.0000 - val_mil_squared_error: 3.7696e-04
# Epoch 126/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.0800 - accuracy: 1.0000 - mil_squared_error: 3.0520e-04 - val_loss: 0.0901 - val_accuracy: 1.0000 - val_mil_squared_error: 3.5658e-04
# Epoch 127/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0692 - accuracy: 1.0000 - mil_squared_error: 2.1694e-04 - val_loss: 0.0886 - val_accuracy: 1.0000 - val_mil_squared_error: 3.4784e-04
# Epoch 128/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0770 - accuracy: 1.0000 - mil_squared_error: 2.1714e-04 - val_loss: 0.0871 - val_accuracy: 1.0000 - val_mil_squared_error: 3.1969e-04
# Epoch 129/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0669 - accuracy: 1.0000 - mil_squared_error: 2.4775e-04 - val_loss: 0.0857 - val_accuracy: 1.0000 - val_mil_squared_error: 2.9942e-04
# Epoch 130/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.0693 - accuracy: 1.0000 - mil_squared_error: 3.6920e-04 - val_loss: 0.0843 - val_accuracy: 1.0000 - val_mil_squared_error: 2.6925e-04
# Epoch 131/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.0689 - accuracy: 1.0000 - mil_squared_error: 1.8251e-04 - val_loss: 0.0830 - val_accuracy: 1.0000 - val_mil_squared_error: 2.5635e-04
# Epoch 132/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.0665 - accuracy: 1.0000 - mil_squared_error: 1.8920e-04 - val_loss: 0.0817 - val_accuracy: 1.0000 - val_mil_squared_error: 2.3493e-04
# Epoch 133/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0663 - accuracy: 1.0000 - mil_squared_error: 9.3291e-05 - val_loss: 0.0804 - val_accuracy: 1.0000 - val_mil_squared_error: 2.2127e-04
# Epoch 134/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.0675 - accuracy: 1.0000 - mil_squared_error: 1.7887e-04 - val_loss: 0.0791 - val_accuracy: 1.0000 - val_mil_squared_error: 2.0681e-04
# Epoch 135/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.0629 - accuracy: 1.0000 - mil_squared_error: 1.8507e-04 - val_loss: 0.0778 - val_accuracy: 1.0000 - val_mil_squared_error: 2.0234e-04
# Epoch 136/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0619 - accuracy: 1.0000 - mil_squared_error: 1.9942e-04 - val_loss: 0.0766 - val_accuracy: 1.0000 - val_mil_squared_error: 1.9908e-04
# Epoch 137/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.0588 - accuracy: 1.0000 - mil_squared_error: 1.8824e-04 - val_loss: 0.0754 - val_accuracy: 1.0000 - val_mil_squared_error: 1.8663e-04
# Epoch 138/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0633 - accuracy: 1.0000 - mil_squared_error: 1.4733e-04 - val_loss: 0.0743 - val_accuracy: 1.0000 - val_mil_squared_error: 1.8328e-04
# Epoch 139/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.0606 - accuracy: 1.0000 - mil_squared_error: 1.4600e-04 - val_loss: 0.0732 - val_accuracy: 1.0000 - val_mil_squared_error: 1.7980e-04
# Epoch 140/150
# 180/180 [==============================] - 0s 659us/step - loss: 0.0593 - accuracy: 1.0000 - mil_squared_error: 1.5923e-04 - val_loss: 0.0721 - val_accuracy: 1.0000 - val_mil_squared_error: 1.7266e-04
# Epoch 141/150
# 180/180 [==============================] - 0s 632us/step - loss: 0.0564 - accuracy: 1.0000 - mil_squared_error: 1.3793e-04 - val_loss: 0.0709 - val_accuracy: 1.0000 - val_mil_squared_error: 1.5888e-04
# Epoch 142/150
# 180/180 [==============================] - 0s 615us/step - loss: 0.0566 - accuracy: 1.0000 - mil_squared_error: 1.0858e-04 - val_loss: 0.0699 - val_accuracy: 1.0000 - val_mil_squared_error: 1.4352e-04
# Epoch 143/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.0597 - accuracy: 1.0000 - mil_squared_error: 8.7181e-05 - val_loss: 0.0689 - val_accuracy: 1.0000 - val_mil_squared_error: 1.2996e-04
# Epoch 144/150
# 180/180 [==============================] - 0s 643us/step - loss: 0.0529 - accuracy: 1.0000 - mil_squared_error: 1.2764e-04 - val_loss: 0.0679 - val_accuracy: 1.0000 - val_mil_squared_error: 1.1935e-04
# Epoch 145/150
# 180/180 [==============================] - 0s 626us/step - loss: 0.0544 - accuracy: 1.0000 - mil_squared_error: 1.3163e-04 - val_loss: 0.0669 - val_accuracy: 1.0000 - val_mil_squared_error: 1.1015e-04
# Epoch 146/150
# 180/180 [==============================] - 0s 654us/step - loss: 0.0509 - accuracy: 1.0000 - mil_squared_error: 1.1994e-04 - val_loss: 0.0660 - val_accuracy: 1.0000 - val_mil_squared_error: 1.0253e-04
# Epoch 147/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0515 - accuracy: 1.0000 - mil_squared_error: 8.8793e-05 - val_loss: 0.0650 - val_accuracy: 1.0000 - val_mil_squared_error: 9.8458e-05
# Epoch 148/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0482 - accuracy: 1.0000 - mil_squared_error: 9.5968e-05 - val_loss: 0.0640 - val_accuracy: 1.0000 - val_mil_squared_error: 9.8519e-05
# Epoch 149/150
# 180/180 [==============================] - 0s 637us/step - loss: 0.0495 - accuracy: 1.0000 - mil_squared_error: 1.0780e-04 - val_loss: 0.0631 - val_accuracy: 1.0000 - val_mil_squared_error: 9.7849e-05
# Epoch 150/150
# 180/180 [==============================] - 0s 648us/step - loss: 0.0490 - accuracy: 1.0000 - mil_squared_error: 8.6847e-05 - val_loss: 0.0622 - val_accuracy: 1.0000 - val_mil_squared_error: 9.1885e-05
# 1.0
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_4_input (InputLay (None, 48, 272)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 24, 500)           272500
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 12, 500)           0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 500)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1536256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# =================================================================
# Total params: 1,808,756
# Trainable params: 1,808,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_emp_miu(X, y):
    outputs = intermediate_layer_model.predict(X)
    norms = [np.linalg.norm(output) for output in outputs]
    emp_miu = np.mean(norms)
    
    path = 'models//emp_miu_class_' + str(y) + '.npy'
    print('emp_miu_class_' + str(y) + ' = ' + str(emp_miu))
    np.save(path, emp_miu)
    return emp_miu

emp_miu_caregiver = get_emp_miu(X_caregiver, 0)
emp_miu_patient = get_emp_miu(X_patient, 1)
# Out:
# emp_miu_class_0 = 5.5180798
# emp_miu_class_1 = 5.364072

# %%
def get_emp_sigma(emp_miu_0, emp_miu_1, X_0, X_1):

    X_0 = intermediate_layer_model.predict(X_0)
    X_1 = intermediate_layer_model.predict(X_1)

    X_0_norms = [np.linalg.norm(x) for x in X_0]
    X_1_norms = [np.linalg.norm(x) for x in X_1]

    class_0 = [ (x-emp_miu_0) * (x-emp_miu_0) for x in X_0_norms] # should be transpose if not just a num
    class_1 = [ (x-emp_miu_1) * (x-emp_miu_1) for x in X_1_norms]
    emp_sigma = np.sum(class_0 + class_1)/(len(class_0) + len(class_1))
    
    '''
    class_0 = [ (x-emp_miu_0) @ np.transpose(x-emp_miu_0) for x in intermediate_layer_model.predict(X_0) ]
    class_1 = [ (x-emp_miu_1) @ np.transpose(x-emp_miu_1) for x in intermediate_layer_model.predict(X_1) ]

    emp_sigma = (class_0 + class_1)/(len(class_0) + len(class_1))
    '''

    print('the emprical covar matrix is ' + str(emp_sigma.shape))

    path = 'models//inv_emp_sigma.npy'

    try:
        result = np.linalg.pinv(emp_sigma)
    except:
        result = emp_sigma

    np.save(path, result)
    return emp_sigma

def get_emp_mahalanobis(X, y):
    mahalanobis_coeff = 0

    emp_miu = np.load('models//emp_miu_class_' + str(y) + '.npy')
    inv_emp_sigma = np.load('models//inv_emp_sigma.npy')

    try:
        mahalanobis_dists = [np.transpose(x-emp_miu) @ inv_emp_sigma @ (x-emp_miu) for x in intermediate_layer_model.predict(X)]
    except:
        mahalanobis_dists = [(x-emp_miu) * inv_emp_sigma * (x-emp_miu) for x in intermediate_layer_model.predict(X)]

    mahalanobis_mean = np.mean(mahalanobis_dists)
    mahalanobis_std = np.std(mahalanobis_dists)

    print('mahalanobis mean for class ' + str(y) + ' is ' + str(mahalanobis_mean))
    print('mahalanobis std for class ' + str(y) + ' is ' + str(mahalanobis_std))

    np.save('models//mahalanobis_mean_class_' + str(y) + '.npy', mahalanobis_mean)
    np.save('models//mahalanobis_std_class_' + str(y) + '.npy', mahalanobis_std)

    # np.linspace(0, 0.1, 200, endpoint=False)
    for coeff in range(0, 100):
        upper = mahalanobis_mean + coeff*mahalanobis_std
        lower = mahalanobis_mean - coeff*mahalanobis_std
        
        valid_xs = []
        for x in intermediate_layer_model.predict(X):
            norm = np.linalg.norm(x)
            
            if norm > lower and norm < upper:
                valid_xs.append(x)

        if len(valid_xs)/len(X) > 0.75:
            print(len(valid_xs)/len(X))
            mahalanobis_coeff = coeff
            np.save('models//mahalanobis_threshold_coefficient_class' + str(y) + '.npy', coeff)
            print('the mahalanobis threshold coefficient for class ' + str(y) + ' is ' + str(coeff))
            break

    return mahalanobis_mean, mahalanobis_std, mahalanobis_coeff


emp_sigma = get_emp_sigma(emp_miu_caregiver, emp_miu_patient, X_caregiver, X_patient)

m_mean_0, m_std_0, m_coeff_0 = get_emp_mahalanobis(X_caregiver, 0)
m_mean_1, m_std_1, m_coeff_1 = get_emp_mahalanobis(X_patient, 1)
# Out:
# the emprical covar matrix is ()
# mahalanobis mean for class 0 is 0.89732885
# mahalanobis std for class 0 is 0.06652558
# 0.7111111111111111
# the mahalanobis threshold coefficient for class 0 is 71
# mahalanobis mean for class 1 is 0.8439298
# mahalanobis std for class 1 is 0.057070866
# 0.7777777777777778
# the mahalanobis threshold coefficient for class 1 is 82

# %%
def load_emp_miu(y):
    path = 'models//emp_miu_class_' + str(y) + '.npy'
    return np.load(path)

def load_inv_emp_covar():
    path = 'models//inv_emp_sigma.npy'
    return np.load(path)

def load_mahalanobis_mean(y):
    path = 'models//mahalanobis_mean_class_' + str(y) + '.npy'
    return np.load(path)

def load_mahalanobis_std(y):
    path = 'models//mahalanobis_std_class_' + str(y) + '.npy'
    return np.load(path)

def load_mahalanobis_coeff(y):
    path = 'models//mahalanobis_threshold_class_' + str(y) + '.npy'
    return np.load(path)

def detect_ood(x, predicted_y):
    
    assert(predicted_y == '0' or predicted_y == '1')
       
    emp_miu = load_emp_miu(y)
    inv_emp_sigma = load_inv_emp_covar()
    m_mean = load_mahalanobis_mean(y)
    m_std = load_mahalanobis_std(y)
    coeff = load_mahalanobis_coeff(y)
    
    upper = m_mean + coeff*m_std
    lower = m_mean - coeff*m_std

    try:
        m_dist = np.transpose(x-emp_miu) @ inv_emp_sigma @ (x-emp_miu)
    except:
        m = (x-emp_miu) * inv_emp_sigma * (x-emp_miu)
    
    if lower < m and m < upper:
        return True
    else:
        return False
